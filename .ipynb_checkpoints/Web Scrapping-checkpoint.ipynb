# %%
import requests 
from bs4 import BeautifulSoup

# %%
URL = "https://summerofcode.withgoogle.com/organizations/"
r = requests.get(URL)

# %%
soup = BeautifulSoup(r.content, 'html5lib') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-apikey="AIzaSyDjInucFVxwjx71SzUUnBY87VBHM6kZcfU" data-appid="summerofcode-prod" data-debug="" data-user-email="" data-version="3-1-6" ga-analytics-id="UA-53341410-6" lang="en" ng-app="app" ng-csp="">
#  <head>
#   <title ng-bind="pageTitle ? pageTitle + ' | Google Summer of Code' : 'Google Summer of Code'">
#   </title>
#   <meta content="zyiCfocOWgOl49GWIo6fZq6DuQ8o-0eXvz1MQP1o5a0" name="google-site-verification"/>
#   <meta content="" name="description"/>
#   <meta content="Google Summer of Code" property="og:title"/>
#   <meta content="" property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://summerofcode.withgoogle.com" property="og:url"/>
#   <meta content="https://summerofcode.withgoogle.com/static/img/og-image.png" property="og:image"/>
#   <link as="font" crossorigin="" href="/static/fonts/material-icons/3.0.1/MaterialIcons-Regular.woff2" rel="preload" type="font/woff2"/>
# ...

# %%
print(soup.div)
# Out:
# <div layout="row" layout-fill="" ng-cloak="">
# 			<div flex="" layout="column" layout-fill="">
# 				<div autoscroll="false" flex="" layout="column" ui-view=""></div>
# 				<div class="toast-parent"></div>
# 			</div>
# 		</div>

# %%
whatweneed = soup.find('div',class_="layout-wrap layout-row")

# %%
print(whatweneed)
# Out:
# None
